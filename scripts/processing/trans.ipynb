# %%
from transformation_pipeline import transformation_pipeline
import os
import pandas as pd

# %%
# Ruta del archivo csv 
FILES_PATH = os.path.join('..','..','data','raw','GeekyMotors')
csv_path = os.path.join(FILES_PATH, 'geeky_motors2.csv')

# Importación del archivo CSV
data = pd.read_csv(csv_path, encoding="latin-1")
data
# Out:
#                                              Nombre      KM Estado  \
# 0                    Tesla Model 3 2018 Bajo Perfil   44000  Usado
# 1                                      Audi Q5 2012  154000  Usado
# 2                                      Audi Q5 2012  154000  Usado
# 3     Toyota Corolla Sport Edition Full Extras 2019   78000  Usado
# 4                                      Audi Q5 2012  154000  Usado
# ...                                             ...     ...    ...
# 4283                             Nissan Almera 2005  150000  Usado
# 4284         Kia Sportage full xtra 2017 Negociable   96000  Usado
# 4285                               BMW X5 3.OD 2014  167000  Usado
# 4286                   Jeep Wrangler Unlimited 2018   78000  Usado
# 4287                              TOYOTA HILUX 2019   83000  Usado
#
#      Combustible Carrocería Tracción Transmisión  \
# 0      Eléctrico      Sedan      4x4  Automática
# 1       Gasolina        SUV      4x2  Automática
# 2       Gasolina        SUV      4x2  Automática
# 3       Gasolina      Sedan      4x2  Automática
# 4       Gasolina        SUV      4x2  Automática
# ...          ...        ...      ...         ...
# 4283    Gasolina      Sedan      4x2  Automática
# 4284    Gasolina        SUV      4x2  Automática
# 4285      Diesel        SUV      4x4  Automática
# 4286    Gasolina        SUV      4x4  Automática
# 4287      Diesel     Pickup      4x4  Automática
#
#                             Asientos           Color  Verificación   Precio
# 0                       Cuero vegano  Red Multi-Coat          93.0  $55,000
# 1                             Cuerro            Gris           NaN   $6,500
# 2                             Cuerro            Gris           NaN   $6,500
# 3                              Cuero     Azul Marino          95.0  $17,500
# 4                             Cuerro            Gris           NaN   $6,500
# ...                              ...             ...           ...      ...
# 4283                            Tela       Rojo Vino           NaN   $3,500
# 4284  Tela, oscuros y áreas de cuero    Negro / gris           NaN  $12,999
# 4285                           cuero           crema           NaN  $18,000
# 4286                            Tela           Beige           NaN  $25,000
# 4287                            Tela            Gris           NaN  $34,995
#
# [4288 rows x 11 columns]

# %%
transformation_pipeline(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pablo\PycharmProjects\Selenium\scrapenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nombre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 transformation_pipeline(data)
#
# File c:\Users\pablo\PycharmProjects\Selenium\scripts\processing\transformation_pipeline.py:10, in transformation_pipeline(df)
#       5 def transformation_pipeline(df):
#       6     df_tmp = pd.DataFrame()
#       9     return (df
# ---> 10         .pipe(tf.estandarizar_marcas)
#      11         .pipe(tf.extraer_marcas)
#      12         .pipe(tf.extraer_anios)
#      13         .pipe(tf.extraer_modelos)
#      14         .pipe(tf.remover_textos)
#      15         .pipe(tf.transformar_sport_edition)
#      16         .pipe(tf.estandarizar_modelos)
#      17         .pipe(tf.transformar_precios)
#      18     )
#
# File c:\Users\pablo\PycharmProjects\Selenium\scrapenv\Lib\site-packages\pandas\core\generic.py:6231, in NDFrame.pipe(self, func, *args, **kwargs)
#    6229 if using_copy_on_write():
#    6230     return common.pipe(self.copy(deep=None), func, *args, **kwargs)
# -> 6231 return common.pipe(self, func, *args, **kwargs)
#
# File c:\Users\pablo\PycharmProjects\Selenium\scrapenv\Lib\site-packages\pandas\core\common.py:502, in pipe(obj, func, *args, **kwargs)
#     500     return func(*args, **kwargs)
#     501 else:
# --> 502     return func(obj, *args, **kwargs)
#
# File c:\Users\pablo\PycharmProjects\Selenium\scripts\processing\transformation_functions.py:57, in estandarizar_marcas(df)
#      54 for clave, valores in reemplazos_marcas.items():
#      55     for valor in valores:
#      56         # Reemplaza cada variante en la columna con la marca estandarizada
# ---> 57         df['nombre'] = df['nombre'].str.replace(valor.lower(), clave, case=False, regex=False)
#      59 return df
#
# File c:\Users\pablo\PycharmProjects\Selenium\scrapenv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\pablo\PycharmProjects\Selenium\scrapenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'nombre'
